# %% [markdown]
# ## Tokenize Input Korean Text into Parts of Speech in Dictionary Form (Original Word)

# %%
from platform import python_version

print(python_version())
# Out:
# 3.8.5

# %%
# pip install JPype1-1.1.2-cp38-cp38-win_amd64.whl

# %%
# pip install konlpy

# %%
from konlpy.tag import Okt
from konlpy.utils import pprint

# %%
text = input("enter text to analyze: ")
okt = Okt()
pprint(okt.pos(text, norm=True, stem=True, join=True))
# Out:
# enter text to analyze: To view keyboard shortcuts, press question mark View keyboard shortcuts Messages 덴 오르술라 107 Tweets See new Tweets 덴 오르술라 @Ors_disorder 덴 오르술라 / 😈 / 1257세 / 30대 초반 / 186cm / 지금부터라도 접속 회복해보겠습니다... 죄송합니다 ㅠㅠ twitter.com/Ors_disorder/s…Joined April 2015 31 Following 30 Followers Not followed by anyone you’re following Tweets Tweets & replies Media Likes 덴 오르술라’s Tweets 덴 오르술라 @Ors_disorder · May 30 엣헴. (목기침 두어번 하고 드르륵 끌고 나온다) 덴 오르술라 @Ors_disorder · May 30 설명하지. 상단 케이크는 고구마 무스를 베이스로, 카라멜을 녹여 상단을 덮은 뒤 초코볼로 데코했다. 글씨 위에 쌀 열 톨을 갈아낸 가루가 덮여있지,  하단 케이크는 맛깔스러운 소곱창을 테두리에 장식, 듬성듬성 케이크 안에도 소곱창이 통 크게 들어가 있다. 캡사이신과 후추의 조합이 알싸해. 덴 오르술라 @Ors_disorder · May 30 곁들이는 음료로는 "금붕어 담금주"라는 이름에 걸맞게 복숭아향 럼주 안에 금붕어가 동동 헤엄치고 있는 게 보이지? 미관적 아름다움과 맛 둘 다 포기하지 못하는 예술적 감각을 볼 수 있을거야. 이상. 덴 오르술라 @Ors_disorder · May 30 얼굴에는 입 말고도 음식을 넣을 수 있는 다양한 구멍이 있지. 덴 오르술라 @Ors_disorder · May 30 천사들 케이크는 생긴게 누구랑 똑같은데... 덴 오르술라 @Ors_disorder · May 30 사회생활은 원래 자다가도 일어나서 케이크 만들고 그런 거죠. (아무렇지 않은 듯...) 덴 오르술라 @Ors_disord
# ...

# %%
import pandas
from pandas import DataFrame

# %%
# Use the okt.pos function and make a dataframe

ttrans = (okt.pos(text, norm=True, stem=True, join=True))
koreanlist = DataFrame(ttrans, columns=['Korean'])

# %%
koreanlist
# Out:
#               Korean
# 0           To/Alpha
# 1         view/Alpha
# 2     keyboard/Alpha
# 3    shortcuts/Alpha
# 4      ,/Punctuation
# ..               ...
# 556      2022/Number
# 557    Twitter/Alpha
# 558    ,/Punctuation
# 559        Inc/Alpha
# 560    ./Punctuation
#
# [561 rows x 1 columns]

# %%
koreanlist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561 entries, 0 to 560
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Korean  561 non-null    object
# dtypes: object(1)
# memory usage: 4.5+ KB

# %%
# remove punctuation in between and sort based on word type for saving

koreanlist['Word'] = koreanlist['Korean'].apply(lambda x: x.split('/')[0])
koreanlist['Type'] = koreanlist['Korean'].apply(lambda x: x.split('/')[1])
koreanlist.drop('Korean', axis=1, inplace=True)

finallist = koreanlist.drop_duplicates()

finallist = finallist[finallist["Type"].str.contains("Alpha|Foreign|Punctuation|Number|Josa|Hashtag|ScreenName|KoreanParticle") == False]

finallist.reset_index(drop=True, inplace=True)

finallist
# Out:
#     Word         Type
# 0      덴         Noun
# 1    오르다         Verb
# 2     술라         Noun
# 3
# 4      세         Noun
# ..   ...          ...
# 169    아  Exclamation
# 170   마음         Noun
# 171  울리다         Verb
# 172   말씀         Noun
# 173   이다         Verb
#
# [174 rows x 2 columns]

# %%
finallist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174 entries, 0 to 173
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Word    174 non-null    object
#  1   Type    174 non-null    object
# dtypes: object(2)
# memory usage: 2.8+ KB

# %%
#counting number of words in each pos

count_pos = finallist.groupby('Type').count()
count_pos
# Out:
#               Word
# Type
#                  1
# Adjective       13
# Adverb           7
# Determiner       1
# Exclamation      1
# Modifier         3
# Noun           113
# Ors_disorder     1
# Suffix           3
# Verb            30
# VerbPrefix       1

# %%
# optional save as a text or csv files
#finallist.to_csv('testout.txt', sep='\t', index=False)
#finallist.to_csv('testout.csv')

# optional save as html
#finallist.to_html('testout.html')

# %% [markdown]
# # Checking the % of top 1000 Words in Input Text

# %%
# Creating a list of words from dataframe 

test_list = finallist['Word'].tolist()

#removing duplicates 

test_list = list(dict.fromkeys(test_list))

test_list
# Out:
# ['덴',
#  '오르다',
#  '술라',
#  '',
#  '세',
#  '대다',
#  '초반',
#  '지금',
#  '접속',
#  '회복',
#  '해보다',
#  '죄송하다',
#  'twitter.com',
#  '엣헴',
#  '목',
#  '기침',
#  '두',
#  '어번',
#  '하다',
#  '드르륵',
#  '끌',
#  '나오다',
#  '설명',
#  '상단',
#  '케이크',
#  '고구마',
#  '무스',
#  '베이스',
#  '카라멜',
#  '녹이다',
#  '덮다',
#  '뒤',
#  '초코',
#  '볼',
#  '데코',
#  '글씨',
#  '위',
#  '쌀',
#  '열',
#  '톨',
#  '갈아',
#  '내다',
#  '가루',
#  '덮이다',
#  '하단',
#  '맛깔',
#  '소',
#  '곱창',
#  '테두리',
#  '장식',
#  '듬성듬성',
#  '안',
#  '통',
#  '크게',
#  '들어가다',
#  '있다',
#  '캡사이신',
#  '후추',
#  '조합',
#  '알싸하다',
#  '곁들이다',
#  '음료',
#  '금붕어',
#  '담그다',
#  '이름',
#  '걸',
#  '맞다',
#  '복숭아',
#  '향',
#  '럼주',
#  '동동',
#  '헤엄',
#  '게',
#  '보이지',
#  '미관',
#  '적',
#  '아름답다',
#  '움',
#  '맛',
#  '둘',
#  '다',
#  '포기',
#  '못',
#  '예술',
#  '감각',
#  '수',
#  '이상',
#  '얼굴',
#  '입',
#  '음식',
#  '넣다',
#  '다양하다',
#  '구멍',
#  '천사',
#  '들',
#  '생기다',
#  '누구',
#  '똑같다',
#  '사회생활',
#  '원래',
#  '자다',
#  '일어나서',
#  '만들다',
#  '그렇다',
#  '거',
#  '아무렇다',
#  '않다',
#  '듯',
# ...

# %%
#length of test word list 

len(test_list)
# Out:
# 174

# %%
# list of top 1000 words

top_1000_list = ['로','나', '는', '그', '의', '하다', '에', '대한', '아르', '오다', '들', '있다', '일', '이', '부터', '의하다', '뜨겁다', '단어', '하지만', '무엇', '다소', '이다', '당신', '또는', '과', '우리', '수', '아웃', '다른', '자신', '시간', '면', '것', '방법', '말', '각', '이야기', '세트', '세', '필요', '공기', '자다', '또한', '재생', '작다', '끝', '넣다', '홈', '읽다', '손', '포트', '크다', '철자', '추가', '도', '땅', '여기', '높다', '이러하다', '따르다', '행위', '이유', '문의', '남자', '변경', '가다', '빛', '종류', '오프', '가', '집', '사진', '시험', '다시', '동물', '포인트', '어머니', '세계', '가깝다', '구축', '자기', '지구', '아버지', '모든', '새롭다', '일부', '소요', '도착', '장소', '만들다', '살다', '어디', '후', '만', '둥글다', '사람', '년', '온', '쇼', '좋다', '나르다', '제공', '아래', '이름', '대단하다', '를', '통해', '단지', '양식', '문장', '생각', '도움', '낮다', '온라인', '차이', '회전', '원인', '많다', '의미', '이전', '움직임', '바로', '소년', '늙다', '너무', '동일', '그녀', '곳', '때', '오르다', '사용', '다음', '쓰기', '같다', '그래서', '기다', '확인', '참조', '두', '보다', '더', '이동', '소리', '없다', '가장', '내', '이상', '알', '고', '물', '통화', '첫째', '수도', '측면', '지금', '발견', '머리', '서다', '페이지', '국가', '답변', '학교', '성장', '연구', '여전하다', '학습', '공장', '덮개', '음식', '네', '사이', '상태', '유지', '눈', '결코', '마지막', '하자', '도시', '트리', '교차', '농장', '단단하다', '시작', '톱', '까지', '바다', '그리다', '왼쪽', '후반', '실행', '반면', '키', '누르다', '가까이', '밤', '실제', '생활', '조금', '북', '책', '수행', '과학', '식사', '방', '친구', '아이디어', '물고기', '산', '중지', '번', '기본', '듣다', '컷', '확실하다', '손목', '시계', '색', '얼굴', '나무', '주', '오픈', '함께', '흰색', '어린이', '도보', '예', '완화', '종이', '그룹', '항상', '음악', '모두', '마르크', '자주', '편지', '마일', '강', '자동차', '피트', '주의', '초', '충분하다', '일반', '소녀', '보통', '젊다', '준비', '되다', '위', '빨간색', '표', '그래도', '느낌', '조류', '곧', '몸', '개', '가족', '직접', '포즈', '떠나다', '노래', '측정', '문', '제품', '블랙', '짧다', '숫자', '클래스', '바람', '질문', '완료', '배', '지역', '반', '바위', '주문', '화재', '남쪽', '문제', '조각', '통과', '이후', '최고', '전체', '왕', '거리', '인치', '곱', '아무', '물론', '휠', '힘', '푸른', '객체', '결정', '표면', '깊다', '달', '섬', '발', '시스템', '바쁘다', '테스트', '기록', '보트', '공통', '금', '가능하다', '비행기', '대신', '건조', '궁금', '웃음', '천', '전', '게임', '모양', '동일시', '미스', '열', '타이어', '멀다', '입력', '동쪽', '페인트', '언어', '중', '단위', '마을', '어떻다', '비행', '가을', '지도', '울음', '어', '두운', '기계', '대기', '계획', '그림', '스타', '상자', '명사', '필드', '나머지', '정확하다', '파운드', '아름답다', '움', '드라이브', '포함', '앞', '가르치다', '최종', '준', '녹색', '오', '빨리', '개발', '대양', '따뜻하다', '무료', '분', '강하다', '특수', '마음', '뒤', '명확하다', '꼬리', '생산', '사실', '공간', '들다', '백', '기억', '단계', '초기', '개최', '서쪽', '지상', '관심', '범위', '빠르다', '동사', '청취', '육', '나타나다', '여행', '이하', '아침', '간단하다', '여러', '모음', '방향', '전쟁', '눕다', '대하', '여', '패턴', '느리다', '센터', '사랑', '돈', '봉사', '표시', '도로', '비', '규칙', '적용', '당기다', '감기', '예고', '음성', '에너지', '사냥', '가능성', '침대', '형제', '계란', '타고', '셀', '어쩌면', '선택', '갑자기', '계산', '광장', '길이', '대표', '예술', '주제', '크기', '다양', '정착', '무게', '얼음', '원', '쌍', '분할', '음절', '그랜드', '공', '아직', '파', '드롭', '현재', '무겁다', '댄스', '엔진', '위치', '팔', '폭', '항해', '재료', '분수', '숲', '앉다', '레이스', '창', '상점', '여름', '기차', '잠', '증명', '고독', '한', '다리', '운동', '벽', '캐치', '마운트', '소원', '하늘', '판', '즐거움', '겨울', '토', '야생', '악기', '유리', '잔디', '소', '작업', '에지', '로그인', '방문', '지난', '소프트', '재미', '밝다', '가스', '날씨', '개월', '곰', '행복', '기대', '꽃', '의복', '을', '걸치다', '기이', '사라', '무역', '멜로디', '사무실', '수신', '행', '입', '기호', '죽다', '수고', '제외', '써다', '씨앗', '톤', '가입', '제안', '청소', '단절', '아가씨', '야드', '상승', '나쁘다', '타격', '기름', '피', '터치', '센트', '혼합', '팀', '와이어', '비용', '손실', '갈색', '착용', '정원', '전송', '하락', '적합', '흐름', '박람회', '은행', '수집', '저장', '제어', '소수점', '귀', '아주', '파산', '경우', '중간', '죽', '아들', '호수', '순간', '규모', '봄', '관찰', '아이', '직선', '자음', '국민', '사전', '우유', '속도', '기관', '지불', '연령', '섹션', '드레스', '구름', '놀람', '조용하다', '돌', '등반', '멋지다', '디자인', '가난하다', '실험', '바닥', '철', '단일', '스틱', '플랫', '스물', '피부', '미소', '주름', '구멍', '점프', '아가', '대회', '루트', '사기', '인상', '해결', '금속', '여부', '푸시', '일곱', '단락', '세번', '째', '야하다', '설명', '요리', '결과', '구울', '언덕', '안전하다', '고양이', '세기', '고려', '유형', '법', '비트', '해안', '복사', '문구', '침묵', '모래', '토양', '롤', '온도', '손가락', '산업', '값', '싸움', '거짓말', '이기다', '흥분', '자연', '보기', '자본', '않다', '의자', '위험', '과일', '풍부하다', '두께', '군인', '과정', '운영', '연습', '별도', '어렵다', '의사', '제발', '보호', '정오', '작물', '현대', '요소', '히트', '학생', '코너', '파티', '공급', '누구', '링', '문자', '곤충', '적발', '기간', '라디오', '원자', '인간', '역사', '효과', '전기', '골', '레일', '상상', '동의', '따라서', '부드럽다', '여성', '주장', '추측', '날카롭다', '날개', '작성', '이웃', '세척', '박쥐', '오히려', '군중', '옥수수', '비교', '시', '문자열', '벨', '고기', '문지', '튜브', '유명하다', '달러', '스트림', '무서움', '시력', '얇다', '삼각형', '행성', '서두르다', '장', '식민지', '넥타이', '주요', '신선하다', '검색', '보내다', '노란색', '총', '인쇄', '자리', '사막', '정장', '리프트', '장미', '마스터', '트랙', '부모', '부문', '시트', '물질', '호의', '연결', '포스트', '지출', '코드', '지방', '다행', '원래', '역', '아빠', '빵', '충전', '적절하다', '바', '세그먼트', '슬레', '이브', '오리', '인스턴트', '시장', '웁니', '다', '병아리', '친애', '적', '응답', '한잔', '발생', '지원', '증기', '모션', '경로', '액체', '지수', '치아', '쉘', '목', '산소', '설탕', '죽음', '꽤', '기술', '시즌', '용액', '자석', '실버', '감사', '지점', '경기', '접미사', '특히', '두렵다', '거대하다', '자매', '스틸', '논의', '으로', '비슷하다', '가이드', '경험', '점수', '사과', '구입', '주도', '피치', '코트', '질량', '카드', '밴드', '로프', '슬립', '승리', '꿈', '저녁', '조건', '먹이', '도구', '냄새', '계곡', '더블', '좌석', '계속', '블록', '차트', '모자', '판매', '성공', '회사', '빼기', '이벤트', '거래', '수영', '용어', '정반대', '아내', '신발', '어깨', '확산', '캠프', '발명', '태어나다', '쿼트', '구', '트럭', '잡음', '수준', '기회', '스트레칭', '던지다', '광택', '등록', '분자', '회색', '반복', '넓다', '소금', '코', '복수', '분노', '제', '대륙']

# %%
# checking the list 
# top_1000_list

# %%
# checking length of top 1000 word list
len(top_1000_list)
# Out:
# 846

# %%
# find words from top 1000 list that are found in input text (common words)

def common_member(a, b):
    result = [i for i in a if i in b]
    return result

print("The common words in the two lists are: ")

common_list = common_member(test_list, top_1000_list)

print(common_list)
# Out:
# The common words in the two lists are:
# ['오르다', '세', '지금', '목', '두', '하다', '설명', '뒤', '위', '열', '소', '있다', '이름', '적', '아름답다', '움', '다', '예술', '수', '이상', '얼굴', '입', '음식', '넣다', '구멍', '들', '누구', '원래', '자다', '만들다', '않다', '아무', '없다', '꼬리', '물론', '보다', '일', '좋다', '여', '아들', '거리', '눈', '소리', '함께', '들다', '당신', '번', '말', '마음', '이다']

# %%
#length of common members list 

len(common_list)
# Out:
# 50

# %%
#calculating the percentage 
print("🆁🅴🆂🆄🅻🆃: ")

print("\033[1m{0}\033[0m of the top 1000 words are used in the input text".format(len(common_list)))

#print("That is, {:0.2f}".format((len(common_list)/len(top_1000_list))*100),"% of top 1000 words")

print("There are \033[1m{0}\033[0m tokenized words in the input text".format(len(test_list)))

#print("What percentage of the list of words in the input text these words make up? ", (len(common_list)/len(test_list))*100 ,"%")

# print("The input text of {2} words contain {0} top {1} words".format(len(common_list),len(top_1000_list),len(test_list) ))

print("That percentage of Top 1000 words in tokenized input text is, \033[1m{:0.2f}".format((len(common_list)/len(test_list))*100),"%\033[0m")
# Out:
# 🆁🅴🆂🆄🅻🆃:
# 50 of the top 1000 words are used in the input text
# There are 174 tokenized words in the input text
# That percentage of Top 1000 words in tokenized input text is, 28.74 %
